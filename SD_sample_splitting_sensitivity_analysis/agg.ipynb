# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import pickle

# %%
with open('Data/d_100_s_10_nr_100_rep_50_c_30_r_01/our_method_metric_list', 'rb') as f:
    our_method_metric_list = pickle.load(f)

runs_precision_list_01 = our_method_metric_list[0]
runs_recall_list_01 = our_method_metric_list[1]
runs_fdr_list_01 = our_method_metric_list[2]
runs_qs_list_01 = our_method_metric_list[3]
# runs_time_mean_list_01 = our_method_metric_list[4]
# runs_time_std_list_01 = our_method_metric_list[5]

runs_fdr_se_list_01 = our_method_metric_list[6]
runs_recall_se_list_01 = our_method_metric_list[7]

# %%
with open('Data/d_100_s_10_nr_100_rep_50_c_30_r_03/our_method_metric_list', 'rb') as f:
    our_method_metric_list = pickle.load(f)

runs_precision_list_03 = our_method_metric_list[0]
runs_recall_list_03 = our_method_metric_list[1]
runs_fdr_list_03 = our_method_metric_list[2]
runs_qs_list_03 = our_method_metric_list[3]
# runs_time_mean_list_03 = our_method_metric_list[4]
# runs_time_std_list_03 = our_method_metric_list[5]
runs_fdr_se_list_03 = our_method_metric_list[6]
runs_recall_se_list_03 = our_method_metric_list[7]

# %%
with open('Data/d_100_s_10_nr_100_rep_50_c_30_r_05/our_method_metric_list', 'rb') as f:
    our_method_metric_list = pickle.load(f)

runs_precision_list_05 = our_method_metric_list[0]
runs_recall_list_05 = our_method_metric_list[1]
runs_fdr_list_05 = our_method_metric_list[2]
runs_qs_list_05 = our_method_metric_list[3]
# runs_time_mean_list_05 = our_method_metric_list[4]
# runs_time_std_list_05 = our_method_metric_list[5]
runs_fdr_se_list_05 = our_method_metric_list[6]
runs_recall_se_list_05 = our_method_metric_list[7]

# %%
with open('Data/d_100_s_10_nr_100_rep_50_c_30_r_07/our_method_metric_list', 'rb') as f:
    our_method_metric_list = pickle.load(f)

runs_precision_list_07 = our_method_metric_list[0]
runs_recall_list_07 = our_method_metric_list[1]
runs_fdr_list_07 = our_method_metric_list[2]
runs_qs_list_07 = our_method_metric_list[3]
# runs_time_mean_list_07 = our_method_metric_list[4]
# runs_time_std_list_07 = our_method_metric_list[5]
runs_fdr_se_list_07 = our_method_metric_list[6]
runs_recall_se_list_07 = our_method_metric_list[7]

# %%
with open('Data/d_100_s_10_nr_100_rep_50_c_30_r_09/our_method_metric_list', 'rb') as f:
    our_method_metric_list = pickle.load(f)

runs_precision_list_09 = our_method_metric_list[0]
runs_recall_list_09 = our_method_metric_list[1]
runs_fdr_list_09 = our_method_metric_list[2]
runs_qs_list_09 = our_method_metric_list[3]
# runs_time_mean_list_09 = our_method_metric_list[4]
# runs_time_std_list_09 = our_method_metric_list[5]
runs_fdr_se_list_09 = our_method_metric_list[6]
runs_recall_se_list_09 = our_method_metric_list[7]

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Create the 4-row, 1-column subplot figure
fig = make_subplots(
    rows=2, cols=5,
    shared_xaxes=False,     
    vertical_spacing=0.07,  
    subplot_titles=["(a)", "(b)", "(c)", "(d)", "(e)"]
)

################################################################################
# Subplot 1 a
################################################################################
run_number = 0

trace2_sub1 = go.Scatter(
    x=runs_qs_list_01[run_number],
    y=runs_fdr_list_01[run_number],
    mode='lines',
    name='DNetEx',
    line=dict(color='rgba(0, 128, 55, 1)'),
    showlegend=True
)

trace3_sub1 = go.Scatter(
    x=[min(runs_qs_list_01[run_number]), max(runs_qs_list_01[run_number])],
    y=[min(runs_qs_list_01[run_number]), max(runs_qs_list_01[run_number])],
    mode='lines',
    name="f(x) = x",
    line=dict(color='black', dash='dash'),
    showlegend=True
)

fig.add_trace(trace2_sub1, row=1, col=1)
fig.add_trace(trace3_sub1, row=1, col=1)
fig.add_trace(go.Scatter(
    x=pd.concat([pd.Series(runs_qs_list_01[run_number]), pd.Series(runs_qs_list_01[run_number])[::-1]]),
    y=pd.concat([pd.Series(runs_fdr_list_01[run_number]) + pd.Series(runs_fdr_se_list_01[run_number]),
                 (pd.Series(runs_fdr_list_01[run_number]) - pd.Series(runs_fdr_se_list_01[run_number]))[::-1]]),
    fill='toself',
    fillcolor='rgba(0, 128, 55, 0.15)',
    line=dict(color='rgba(255,255,255,0)'),
    showlegend=False,
    hoverinfo="skip"
), row=1, col=1)

fig.update_xaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=1, col=1
)
fig.update_yaxes(
    title_text="Real FDR", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=1, col=1
)

################################################################################
# Subplot 2 b
################################################################################
trace2_sub2 = go.Scatter(
    x=runs_qs_list_03[run_number],
    y=runs_fdr_list_03[run_number],
    mode='lines',
    name='Our Method, p=100',
    line=dict(color='rgba(0, 128, 55, 1)'),
    showlegend=False
)

trace3_sub2 = go.Scatter(
    x=[min(runs_qs_list_03[run_number]), max(runs_qs_list_03[run_number])],
    y=[min(runs_qs_list_03[run_number]), max(runs_qs_list_03[run_number])],
    mode='lines',
    name="f(x) = x",
    line=dict(color='black', dash='dash'),
    showlegend=False
)

fig.add_trace(trace2_sub2, row=1, col=2)
fig.add_trace(trace3_sub2, row=1, col=2)
fig.add_trace(go.Scatter(
    x=pd.concat([pd.Series(runs_qs_list_03[run_number]), pd.Series(runs_qs_list_03[run_number])[::-1]]),
    y=pd.concat([pd.Series(runs_fdr_list_03[run_number]) + pd.Series(runs_fdr_se_list_03[run_number]),
                 (pd.Series(runs_fdr_list_03[run_number]) - pd.Series(runs_fdr_se_list_03[run_number]))[::-1]]),
    fill='toself',
    fillcolor='rgba(0, 128, 55, 0.15)',
    line=dict(color='rgba(255,255,255,0)'),
    showlegend=False,
    hoverinfo="skip"
), row=1, col=2)

fig.update_xaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=1, col=2
)
fig.update_yaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=1, col=2
)

################################################################################
# Subplot 3 c
################################################################################
trace2_sub3 = go.Scatter(
    x=runs_qs_list_05[run_number],
    y=runs_fdr_list_05[run_number],
    mode='lines',
    name='Our Method, p=100',
    line=dict(color='rgba(0, 128, 55, 1)'),
    showlegend=False
)

trace3_sub3 = go.Scatter(
    x=[min(runs_qs_list_05[run_number]), max(runs_qs_list_05[run_number])],
    y=[min(runs_qs_list_05[run_number]), max(runs_qs_list_05[run_number])],
    mode='lines',
    name="f(x) = x",
    line=dict(color='black', dash='dash'),
    showlegend=False
)

fig.add_trace(trace2_sub3, row=1, col=3)
fig.add_trace(trace3_sub3, row=1, col=3)
fig.add_trace(go.Scatter(
    x=pd.concat([pd.Series(runs_qs_list_05[run_number]), pd.Series(runs_qs_list_05[run_number])[::-1]]),
    y=pd.concat([pd.Series(runs_fdr_list_05[run_number]) + pd.Series(runs_fdr_se_list_05[run_number]),
                 (pd.Series(runs_fdr_list_05[run_number]) - pd.Series(runs_fdr_se_list_05[run_number]))[::-1]]),
    fill='toself',
    fillcolor='rgba(0, 128, 55, 0.15)',
    line=dict(color='rgba(255,255,255,0)'),
    showlegend=False,
    hoverinfo="skip"
), row=1, col=3)

fig.update_xaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=1, col=3
)
fig.update_yaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=1, col=3
)

################################################################################
# Subplot 4 d
################################################################################
trace2_sub4 = go.Scatter(
    x=runs_qs_list_07[run_number],
    y=runs_fdr_list_07[run_number],
    mode='lines',
    name='Our Method, p=100',
    line=dict(color='rgba(0, 128, 55, 1)'),
    showlegend=False
)

trace3_sub4 = go.Scatter(
    x=[min(runs_qs_list_07[run_number]), max(runs_qs_list_07[run_number])],
    y=[min(runs_qs_list_07[run_number]), max(runs_qs_list_07[run_number])],
    mode='lines',
    name="f(x) = x",
    line=dict(color='black', dash='dash'),
    showlegend=False
)

fig.add_trace(trace2_sub4, row=1, col=4)
fig.add_trace(trace3_sub4, row=1, col=4)
fig.add_trace(go.Scatter(
    x=pd.concat([pd.Series(runs_qs_list_07[run_number]), pd.Series(runs_qs_list_07[run_number])[::-1]]),
    y=pd.concat([pd.Series(runs_fdr_list_07[run_number]) + pd.Series(runs_fdr_se_list_07[run_number]),
                 (pd.Series(runs_fdr_list_07[run_number]) - pd.Series(runs_fdr_se_list_07[run_number]))[::-1]]),
    fill='toself',
    fillcolor='rgba(0, 128, 55, 0.15)',
    line=dict(color='rgba(255,255,255,0)'),
    showlegend=False,
    hoverinfo="skip"
), row=1, col=4)

fig.update_xaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=1, col=4
)
fig.update_yaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=1, col=4
)

################################################################################
# Subplot 5 e
################################################################################
trace2_sub5 = go.Scatter(
    x=runs_qs_list_09[run_number],
    y=runs_fdr_list_09[run_number],
    mode='lines',
    name='Our Method, p=100',
    line=dict(color='rgba(0, 128, 55, 1)'),
    showlegend=False
)

trace3_sub5 = go.Scatter(
    x=[min(runs_qs_list_09[run_number]), max(runs_qs_list_09[run_number])],
    y=[min(runs_qs_list_09[run_number]), max(runs_qs_list_09[run_number])],
    mode='lines',
    name="f(x) = x",
    line=dict(color='black', dash='dash'),
    showlegend=False
)

fig.add_trace(trace2_sub5, row=1, col=5)
fig.add_trace(trace3_sub5, row=1, col=5)
fig.add_trace(go.Scatter(
    x=pd.concat([pd.Series(runs_qs_list_09[run_number]), pd.Series(runs_qs_list_09[run_number])[::-1]]),
    y=pd.concat([pd.Series(runs_fdr_list_09[run_number]) + pd.Series(runs_fdr_se_list_09[run_number]),
                 (pd.Series(runs_fdr_list_09[run_number]) - pd.Series(runs_fdr_se_list_09[run_number]))[::-1]]),
    fill='toself',
    fillcolor='rgba(0, 128, 55, 0.15)',
    line=dict(color='rgba(255,255,255,0)'),
    showlegend=False,
    hoverinfo="skip"
), row=1, col=5)

fig.update_xaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=1, col=5
)
fig.update_yaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=1, col=5
)



################################################################################
# Subplot 2 1
################################################################################
trace2_sub1 = go.Scatter(
    x=runs_qs_list_01[run_number],
    y=runs_recall_list_01[run_number],
    mode='lines',
    name='Our Method, p=100',
    line=dict(color='rgba(0, 128, 55, 1)'),
    showlegend=False
)

fig.add_trace(go.Scatter(
    x=pd.concat([pd.Series(runs_qs_list_01[run_number]), pd.Series(runs_qs_list_01[run_number])[::-1]]),
    y=pd.concat([pd.Series(runs_recall_list_01[run_number]) + pd.Series(runs_recall_se_list_01[run_number]),
                 (pd.Series(runs_recall_list_01[run_number]) - pd.Series(runs_recall_se_list_01[run_number]))[::-1]]),
    fill='toself',
    fillcolor='rgba(0, 128, 55, 0.15)',
    line=dict(color='rgba(255,255,255,0)'),
    showlegend=False,
    hoverinfo="skip"
), row=2, col=1)

fig.add_trace(trace2_sub1, row=2, col=1)

fig.update_xaxes(
    title_text="Control FDR", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=2, col=1
)
fig.update_yaxes(
    title_text="Recall", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=2, col=1
)


################################################################################
# Subplot 2 2
################################################################################
trace2_sub2 = go.Scatter(
    x=runs_qs_list_03[run_number],
    y=runs_recall_list_03[run_number],
    mode='lines',
    name='Our Method, p=100',
    line=dict(color='rgba(0, 128, 55, 1)'),
    showlegend=False
)
fig.add_trace(go.Scatter(
    x=pd.concat([pd.Series(runs_qs_list_03[run_number]), pd.Series(runs_qs_list_03[run_number])[::-1]]),
    y=pd.concat([pd.Series(runs_recall_list_03[run_number]) + pd.Series(runs_recall_se_list_03[run_number]),
                 (pd.Series(runs_recall_list_03[run_number]) - pd.Series(runs_recall_se_list_03[run_number]))[::-1]]),
    fill='toself',
    fillcolor='rgba(0, 128, 55, 0.15)',
    line=dict(color='rgba(255,255,255,0)'),
    showlegend=False,
    hoverinfo="skip"
), row=2, col=2)

fig.add_trace(trace2_sub2, row=2, col=2)

fig.update_xaxes(
    title_text="Control FDR", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=2, col=2
)
fig.update_yaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=2, col=2
)

################################################################################
# Subplot 2 3
################################################################################
trace2_sub6 = go.Scatter(
    x=runs_qs_list_05[run_number],
    y=runs_recall_list_05[run_number],
    mode='lines',
    name='Our Method, p=100',
    line=dict(color='rgba(0, 128, 55, 1)'),
    showlegend=False
)
fig.add_trace(go.Scatter(
    x=pd.concat([pd.Series(runs_qs_list_05[run_number]), pd.Series(runs_qs_list_05[run_number])[::-1]]),
    y=pd.concat([pd.Series(runs_recall_list_05[run_number]) + pd.Series(runs_recall_se_list_05[run_number]),
                 (pd.Series(runs_recall_list_05[run_number]) - pd.Series(runs_recall_se_list_05[run_number]))[::-1]]),
    fill='toself',
    fillcolor='rgba(0, 128, 55, 0.15)',
    line=dict(color='rgba(255,255,255,0)'),
    showlegend=False,
    hoverinfo="skip"
), row=2, col=3)

fig.add_trace(trace2_sub6, row=2, col=3)

fig.update_xaxes(
    title_text="Control FDR", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=2, col=3
)
fig.update_yaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=2, col=4
)

################################################################################
# Subplot 2 4
################################################################################
trace2_sub4 = go.Scatter(
    x=runs_qs_list_07[run_number],
    y=runs_recall_list_07[run_number],
    mode='lines',
    name='Our Method, p=100',
    line=dict(color='rgba(0, 128, 55, 1)'),
    showlegend=False
)
fig.add_trace(go.Scatter(
    x=pd.concat([pd.Series(runs_qs_list_07[run_number]), pd.Series(runs_qs_list_07[run_number])[::-1]]),
    y=pd.concat([pd.Series(runs_recall_list_07[run_number]) + pd.Series(runs_recall_se_list_07[run_number]),
                 (pd.Series(runs_recall_list_07[run_number]) - pd.Series(runs_recall_se_list_07[run_number]))[::-1]]),
    fill='toself',
    fillcolor='rgba(0, 128, 55, 0.15)',
    line=dict(color='rgba(255,255,255,0)'),
    showlegend=False,
    hoverinfo="skip"
), row=2, col=4)

fig.add_trace(trace2_sub4, row=2, col=4)

fig.update_xaxes(
    title_text="Control FDR", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=2, col=4
)
fig.update_yaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=2, col=4
)

################################################################################
# Subplot 2 5
################################################################################
trace2_sub5 = go.Scatter(
    x=runs_qs_list_09[run_number],
    y=runs_recall_list_09[run_number],
    mode='lines',
    name='Our Method, p=100',
    line=dict(color='rgba(0, 128, 55, 1)'),
    showlegend=False
)
fig.add_trace(go.Scatter(
    x=pd.concat([pd.Series(runs_qs_list_09[run_number]), pd.Series(runs_qs_list_09[run_number])[::-1]]),
    y=pd.concat([pd.Series(runs_recall_list_09[run_number]) + pd.Series(runs_recall_se_list_09[run_number]),
                 (pd.Series(runs_recall_list_09[run_number]) - pd.Series(runs_recall_se_list_09[run_number]))[::-1]]),
    fill='toself',
    fillcolor='rgba(0, 128, 55, 0.15)',
    line=dict(color='rgba(255,255,255,0)'),
    showlegend=False,
    hoverinfo="skip"
), row=2, col=5)

fig.add_trace(trace2_sub5, row=2, col=5)

fig.update_xaxes(
    title_text="Control FDR", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=2, col=5
)
fig.update_yaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=2, col=5
)



################################################################################
# Global Layout (Only Subplot 1's traces appear in the legend)
################################################################################
fig.update_traces(line=dict(width=3))
fig.update_layout(
    xaxis1=dict(tickfont=dict(size=16),showticklabels=False),
    xaxis2=dict(tickfont=dict(size=16),showticklabels=False),
    xaxis3=dict(tickfont=dict(size=16),showticklabels=False),
    xaxis4=dict(tickfont=dict(size=16),showticklabels=False),
    xaxis5=dict(tickfont=dict(size=16),showticklabels=False),
    xaxis6=dict(tickfont=dict(size=16)),
    xaxis7=dict(tickfont=dict(size=16)),
    xaxis8=dict(tickfont=dict(size=16)),
    xaxis9=dict(tickfont=dict(size=16)),
    xaxis10=dict(tickfont=dict(size=16)),
    yaxis1=dict(tickfont=dict(size=16)),
    yaxis2=dict(tickfont=dict(size=16),showticklabels=False),
    yaxis3=dict(tickfont=dict(size=16),showticklabels=False),
    yaxis4=dict(tickfont=dict(size=16),showticklabels=False),
    yaxis5=dict(tickfont=dict(size=16),showticklabels=False),
    yaxis6=dict(tickfont=dict(size=16)),
    yaxis7=dict(tickfont=dict(size=16),showticklabels=False),
    yaxis8=dict(tickfont=dict(size=16),showticklabels=False),
    yaxis9=dict(tickfont=dict(size=16),showticklabels=False),
    yaxis10=dict(tickfont=dict(size=16),showticklabels=False),
    autosize=False,
    width=2000,
    height=700,
    plot_bgcolor='white',
    paper_bgcolor='white',
    margin=dict(l=50, r=50, t=50, b=50),
    showlegend=True,
    legend=dict(
        x=0.005,
        y=0.995,
        xanchor='left',
        yanchor='top',
        bgcolor='white',
        bordercolor='gray',
        borderwidth=1
    ),
    font=dict(size=16)
)

fig.show()

fig.write_image("Results/sample_splitting_sensitivity_analysis.pdf")

# %%
run_number = 0

# Create figure
fig = go.Figure()

fig.add_trace(
    go.Scatter(
        x=runs_recall_list_05[run_number],
        y=1-runs_fdr_list_05[run_number],
        mode='lines+markers',
        name=f'DNetEx, p=100'
    )
)

# Customize the layout
fig.update_traces(line=dict(width=3))

fig.update_layout(
    xaxis1=dict(tickfont=dict(size=16),showticklabels=True),
    yaxis1=dict(tickfont=dict(size=16),showticklabels=True),
    autosize=False,
    width=800,
    height=500,
    xaxis_title=r"Recall",
    yaxis_title='Precision',
    plot_bgcolor='white',
    paper_bgcolor='white',
    margin=dict(l=50, r=50, t=50, b=50),
    showlegend=True,
    legend=dict(
        x=.995,
        y=0.99,  
        xanchor='right',
        yanchor='top',
        bgcolor='rgba(255, 255, 255, 0.6)',
        bordercolor='gray',
        borderwidth=1
    ),
    xaxis=dict(showline=True, linewidth=2, linecolor='black', mirror=True),
    yaxis=dict(showline=True, linewidth=2, linecolor='black', mirror=True),
    font=dict(size=16)

)

fig.show()

fig.write_image("Results/pr.pdf")
