# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import pickle

# %%
r1_00 = pd.read_csv('Data/d_100_200_s_10_nr_10_rep_50_c_30_g_00/100_sgn_metric_list_hist_DiffNetFDR_Liu2017.csv')
r2_00 = pd.read_csv('Data/d_100_200_s_10_nr_10_rep_50_c_30_g_00/200_sgn_metric_list_hist_DiffNetFDR_Liu2017.csv')
x1_00 = pd.read_csv('Data/d_100_200_s_10_nr_10_rep_50_c_30_g_00/100_sgn_metric_list_hist_DiffNetFDR_Xia2015.csv')
x2_00 = pd.read_csv('Data/d_100_200_s_10_nr_10_rep_50_c_30_g_00/200_sgn_metric_list_hist_DiffNetFDR_Xia2015.csv')


with open('Data/d_100_200_s_10_nr_10_rep_50_c_30_g_00/our_method_metric_list', 'rb') as f:
    our_method_metric_list = pickle.load(f)

runs_precision_list_00 = our_method_metric_list[0]
runs_recall_list_00 = our_method_metric_list[1]
runs_fdr_list_00 = our_method_metric_list[2]
runs_qs_list_00 = our_method_metric_list[3]

# %%
r1_02 = pd.read_csv('Data/d_100_200_s_10_nr_10_rep_50_c_30_g_02/100_sgn_metric_list_hist_DiffNetFDR_Liu2017.csv')
r2_02 = pd.read_csv('Data/d_100_200_s_10_nr_10_rep_50_c_30_g_02/200_sgn_metric_list_hist_DNetFinder.csv')
x1_02 = pd.read_csv('Data/d_100_200_s_10_nr_10_rep_50_c_30_g_02/100_sgn_metric_list_hist_DiffNetFDR_Xia2015.csv')


with open('Data/d_100_200_s_10_nr_10_rep_50_c_30_g_02/our_method_metric_list', 'rb') as f:
    our_method_metric_list = pickle.load(f)

runs_precision_list_02 = our_method_metric_list[0]
runs_recall_list_02 = our_method_metric_list[1]
runs_fdr_list_02 = our_method_metric_list[2]
runs_qs_list_02 = our_method_metric_list[3]

# %%
r1_04 = pd.read_csv('Data/d_100_200_s_10_nr_10_rep_50_c_30_g_04/100_sgn_metric_list_hist_DiffNetFDR_Liu2017.csv')
r2_04 = pd.read_csv('Data/d_100_200_s_10_nr_10_rep_50_c_30_g_04/200_sgn_metric_list_hist_DNetFinder.csv')
x1_04 = pd.read_csv('Data/d_100_200_s_10_nr_10_rep_50_c_30_g_04/100_sgn_metric_list_hist_DiffNetFDR_Xia2015.csv')


with open('Data/d_100_200_s_10_nr_10_rep_50_c_30_g_04/our_method_metric_list', 'rb') as f:
    our_method_metric_list = pickle.load(f)

runs_precision_list_04 = our_method_metric_list[0]
runs_recall_list_04 = our_method_metric_list[1]
runs_fdr_list_04 = our_method_metric_list[2]
runs_qs_list_04 = our_method_metric_list[3]

# %%
r1_06 = pd.read_csv('Data/d_100_200_s_10_nr_10_rep_50_c_30_g_06/100_sgn_metric_list_hist_DiffNetFDR_Liu2017.csv')
r2_06 = pd.read_csv('Data/d_100_200_s_10_nr_10_rep_50_c_30_g_06/200_sgn_metric_list_hist_DNetFinder.csv')
x1_06 = pd.read_csv('Data/d_100_200_s_10_nr_10_rep_50_c_30_g_06/100_sgn_metric_list_hist_DiffNetFDR_Xia2015.csv')


with open('Data/d_100_200_s_10_nr_10_rep_50_c_30_g_06/our_method_metric_list', 'rb') as f:
    our_method_metric_list = pickle.load(f)

runs_precision_list_06 = our_method_metric_list[0]
runs_recall_list_06 = our_method_metric_list[1]
runs_fdr_list_06 = our_method_metric_list[2]
runs_qs_list_06 = our_method_metric_list[3]

# %%
r1_08 = pd.read_csv('Data/d_100_200_s_10_nr_10_rep_50_c_30_g_08/100_sgn_metric_list_hist_DiffNetFDR_Liu2017.csv')
r2_08 = pd.read_csv('Data/d_100_200_s_10_nr_10_rep_50_c_30_g_08/200_sgn_metric_list_hist_DNetFinder.csv')
x1_08 = pd.read_csv('Data/d_100_200_s_10_nr_10_rep_50_c_30_g_08/100_sgn_metric_list_hist_DiffNetFDR_Xia2015.csv')


with open('Data/d_100_200_s_10_nr_10_rep_50_c_30_g_08/our_method_metric_list', 'rb') as f:
    our_method_metric_list = pickle.load(f)

runs_precision_list_08 = our_method_metric_list[0]
runs_recall_list_08 = our_method_metric_list[1]
runs_fdr_list_08 = our_method_metric_list[2]
runs_qs_list_08 = our_method_metric_list[3]

# %%
r1_10 = pd.read_csv('Data/d_100_200_s_10_nr_10_rep_50_c_30_g_10/100_sgn_metric_list_hist_DiffNetFDR_Liu2017.csv')
r2_10 = pd.read_csv('Data/d_100_200_s_10_nr_10_rep_50_c_30_g_10/200_sgn_metric_list_hist_DNetFinder.csv')
x1_10 = pd.read_csv('Data/d_100_200_s_10_nr_10_rep_50_c_30_g_10/100_sgn_metric_list_hist_DiffNetFDR_Xia2015.csv')


with open('Data/d_100_200_s_10_nr_10_rep_50_c_30_g_10/our_method_metric_list', 'rb') as f:
    our_method_metric_list = pickle.load(f)

runs_precision_list_10 = our_method_metric_list[0]
runs_recall_list_10 = our_method_metric_list[1]
runs_fdr_list_10 = our_method_metric_list[2]
runs_qs_list_10 = our_method_metric_list[3]

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Create the 4-row, 1-column subplot figure
fig = make_subplots(
    rows=2, cols=6,
    shared_xaxes=False,     
    vertical_spacing=0.07,  
    subplot_titles=["(a)", "(b)", "(c)", "(d)", "(e)", "(f)"]
)

################################################################################
# Subplot 1 a
################################################################################
temp_df = r1_00.groupby('alpha').FDR.mean().reset_index()
temp_dfx = x1_00.groupby('alpha').FDR.mean().reset_index()
run_number = 0

trace1_sub1 = go.Scatter(
    x=temp_df.alpha.values,
    y=temp_df.FDR.values,
    mode='lines',
    name='pcor',
    line=dict(color='blue'),    # <--- Explicit color
    showlegend=True
)

trace1x_sub1 = go.Scatter(
    x=temp_dfx.alpha.values,
    y=temp_dfx.FDR.values,
    mode='lines',
    name='pmat',
    line=dict(color='green'),    # <--- Explicit color
    showlegend=True
)

trace2_sub1 = go.Scatter(
    x=runs_qs_list_00[run_number],
    y=runs_fdr_list_00[run_number],
    mode='lines',
    name='DNetEx',
    line=dict(color='red'),     # <--- Explicit color
    showlegend=True
)

trace3_sub1 = go.Scatter(
    x=[min(runs_qs_list_00[run_number]), max(runs_qs_list_00[run_number])],
    y=[min(runs_qs_list_00[run_number]), max(runs_qs_list_00[run_number])],
    mode='lines',
    name="f(x) = x",
    line=dict(color='black', dash='dash'),  # <--- Explicit color/dash
    showlegend=True
)

fig.add_trace(trace1_sub1, row=1, col=1)
fig.add_trace(trace1x_sub1, row=1, col=1)
fig.add_trace(trace2_sub1, row=1, col=1)
fig.add_trace(trace3_sub1, row=1, col=1)

fig.update_xaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=1, col=1
)
fig.update_yaxes(
    title_text="Dimension1=00 <br><br> Real FDR", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=1, col=1
)

################################################################################
# Subplot 2 b
################################################################################
temp_df = r1_02.groupby('alpha').FDR.mean().reset_index()
temp_dfx = x1_02.groupby('alpha').FDR.mean().reset_index()

trace1_sub2 = go.Scatter(
    x=temp_df.alpha.values,
    y=temp_df.FDR.values,
    mode='lines',
    name='pcor',
    line=dict(color='blue'),
    showlegend=False
)

trace1x_sub2 = go.Scatter(
    x=temp_dfx.alpha.values,
    y=temp_dfx.FDR.values,
    mode='lines',
    name='pmat',
    line=dict(color='green'),
    showlegend=False
)

trace2_sub2 = go.Scatter(
    x=runs_qs_list_02[run_number],
    y=runs_fdr_list_02[run_number],
    mode='lines',
    name='Our Method, p=100',
    line=dict(color='red'),
    showlegend=False
)

trace3_sub2 = go.Scatter(
    x=[min(runs_qs_list_02[run_number]), max(runs_qs_list_02[run_number])],
    y=[min(runs_qs_list_02[run_number]), max(runs_qs_list_02[run_number])],
    mode='lines',
    name="f(x) = x",
    line=dict(color='black', dash='dash'),
    showlegend=False
)

fig.add_trace(trace1_sub2, row=1, col=2)
fig.add_trace(trace1x_sub2, row=1, col=2)
fig.add_trace(trace2_sub2, row=1, col=2)
fig.add_trace(trace3_sub2, row=1, col=2)

fig.update_xaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=1, col=2
)
fig.update_yaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=1, col=2
)
################################################################################
# Subplot 3 c
################################################################################
temp_df = r1_04.groupby('alpha').FDR.mean().reset_index()
temp_dfx = x1_04.groupby('alpha').FDR.mean().reset_index()

trace1_sub3 = go.Scatter(
    x=temp_df.alpha.values,
    y=temp_df.FDR.values,
    mode='lines',
    name='pcor',
    line=dict(color='blue'),
    showlegend=False
)

trace1x_sub3 = go.Scatter(
    x=temp_dfx.alpha.values,
    y=temp_dfx.FDR.values,
    mode='lines',
    name='pmat',
    line=dict(color='green'),
    showlegend=False
)

trace2_sub3 = go.Scatter(
    x=runs_qs_list_04[run_number],
    y=runs_fdr_list_04[run_number],
    mode='lines',
    name='Our Method, p=100',
    line=dict(color='red'),
    showlegend=False
)

trace3_sub3 = go.Scatter(
    x=[min(runs_qs_list_04[run_number]), max(runs_qs_list_04[run_number])],
    y=[min(runs_qs_list_04[run_number]), max(runs_qs_list_04[run_number])],
    mode='lines',
    name="f(x) = x",
    line=dict(color='black', dash='dash'),
    showlegend=False
)

fig.add_trace(trace1_sub3, row=1, col=3)
fig.add_trace(trace1x_sub3, row=1, col=3)
fig.add_trace(trace2_sub3, row=1, col=3)
fig.add_trace(trace3_sub3, row=1, col=3)

fig.update_xaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=1, col=3
)
fig.update_yaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=1, col=3
)

################################################################################
# Subplot 4 d
################################################################################
temp_df = r1_06.groupby('alpha').FDR.mean().reset_index()
temp_dfx = x1_06.groupby('alpha').FDR.mean().reset_index()

trace1_sub4 = go.Scatter(
    x=temp_df.alpha.values,
    y=temp_df.FDR.values,
    mode='lines',
    name='pcor',
    line=dict(color='blue'),
    showlegend=False
)

trace1x_sub4 = go.Scatter(
    x=temp_dfx.alpha.values,
    y=temp_dfx.FDR.values,
    mode='lines',
    name='pmat',
    line=dict(color='green'),
    showlegend=False
)

trace2_sub4 = go.Scatter(
    x=runs_qs_list_06[run_number],
    y=runs_fdr_list_06[run_number],
    mode='lines',
    name='Our Method, p=100',
    line=dict(color='red'),
    showlegend=False
)

trace3_sub4 = go.Scatter(
    x=[min(runs_qs_list_06[run_number]), max(runs_qs_list_06[run_number])],
    y=[min(runs_qs_list_06[run_number]), max(runs_qs_list_06[run_number])],
    mode='lines',
    name="f(x) = x",
    line=dict(color='black', dash='dash'),
    showlegend=False
)

fig.add_trace(trace1_sub4, row=1, col=4)
fig.add_trace(trace1x_sub4, row=1, col=4)
fig.add_trace(trace2_sub4, row=1, col=4)
fig.add_trace(trace3_sub4, row=1, col=4)

fig.update_xaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=1, col=4
)
fig.update_yaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=1, col=4
)

################################################################################
# Subplot 5 e
################################################################################
temp_df = r1_08.groupby('alpha').FDR.mean().reset_index()
temp_dfx = x1_08.groupby('alpha').FDR.mean().reset_index()

trace1_sub5 = go.Scatter(
    x=temp_df.alpha.values,
    y=temp_df.FDR.values,
    mode='lines',
    name='pcor',
    line=dict(color='blue'),
    showlegend=False
)

trace1x_sub5 = go.Scatter(
    x=temp_dfx.alpha.values,
    y=temp_dfx.FDR.values,
    mode='lines',
    name='pmat',
    line=dict(color='green'),
    showlegend=False
)

trace2_sub5 = go.Scatter(
    x=runs_qs_list_08[run_number],
    y=runs_fdr_list_08[run_number],
    mode='lines',
    name='Our Method, p=100',
    line=dict(color='red'),
    showlegend=False
)

trace3_sub5 = go.Scatter(
    x=[min(runs_qs_list_08[run_number]), max(runs_qs_list_08[run_number])],
    y=[min(runs_qs_list_08[run_number]), max(runs_qs_list_08[run_number])],
    mode='lines',
    name="f(x) = x",
    line=dict(color='black', dash='dash'),
    showlegend=False
)

fig.add_trace(trace1_sub5, row=1, col=5)
fig.add_trace(trace1x_sub5, row=1, col=5)
fig.add_trace(trace2_sub5, row=1, col=5)
fig.add_trace(trace3_sub5, row=1, col=5)

fig.update_xaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=1, col=5
)
fig.update_yaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=1, col=5
)

################################################################################
# Subplot 6
################################################################################
temp_df = r1_10.groupby('alpha').FDR.mean().reset_index()
temp_dfx = x1_10.groupby('alpha').FDR.mean().reset_index()

trace1_sub6 = go.Scatter(
    x=temp_df.alpha.values,
    y=temp_df.FDR.values,
    mode='lines',
    name='pcor',
    line=dict(color='blue'),
    showlegend=False
)

trace1x_sub6 = go.Scatter(
    x=temp_dfx.alpha.values,
    y=temp_dfx.FDR.values,
    mode='lines',
    name='pmat',
    line=dict(color='green'),
    showlegend=False
)

trace2_sub6 = go.Scatter(
    x=runs_qs_list_10[run_number],
    y=runs_fdr_list_10[run_number],
    mode='lines',
    name='Our Method, p=100',
    line=dict(color='red'),
    showlegend=False
)

trace3_sub6 = go.Scatter(
    x=[min(runs_qs_list_10[run_number]), max(runs_qs_list_10[run_number])],
    y=[min(runs_qs_list_10[run_number]), max(runs_qs_list_10[run_number])],
    mode='lines',
    name="f(x) = x",
    line=dict(color='black', dash='dash'),
    showlegend=False
)

fig.add_trace(trace1_sub6, row=1, col=6)
fig.add_trace(trace1x_sub6, row=1, col=6)
fig.add_trace(trace2_sub6, row=1, col=6)
fig.add_trace(trace3_sub6, row=1, col=6)

fig.update_xaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=1, col=6
)
fig.update_yaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=1, col=6
)



################################################################################
# Subplot 2 1
################################################################################
temp_df = r2_00.groupby('alpha').FDR.mean().reset_index()
temp_dfx = x2_00.groupby('alpha').FDR.mean().reset_index()
run_number = 0

trace1_sub1 = go.Scatter(
    x=temp_df.alpha.values,
    y=temp_df.FDR.values,
    mode='lines',
    name='pcor, p=100',
    line=dict(color='blue'),    # <--- Explicit color
    showlegend=False
)

trace1x_sub1 = go.Scatter(
    x=temp_dfx.alpha.values,
    y=temp_dfx.FDR.values,
    mode='lines',
    name='pmat, p=100',
    line=dict(color='green'),    # <--- Explicit color
    showlegend=False
)

trace2_sub1 = go.Scatter(
    x=runs_qs_list_00[run_number],
    y=runs_fdr_list_00[run_number],
    mode='lines',
    name='Our Method, p=100',
    line=dict(color='red'),     # <--- Explicit color
    showlegend=False
)

trace3_sub1 = go.Scatter(
    x=[min(runs_qs_list_00[run_number]), max(runs_qs_list_00[run_number])],
    y=[min(runs_qs_list_00[run_number]), max(runs_qs_list_00[run_number])],
    mode='lines',
    name="f(x) = x",
    line=dict(color='black', dash='dash'),  # <--- Explicit color/dash
    showlegend=False
)

fig.add_trace(trace1_sub1, row=2, col=1)
fig.add_trace(trace1x_sub1, row=2, col=1)
fig.add_trace(trace2_sub1, row=2, col=1)
fig.add_trace(trace3_sub1, row=2, col=1)

fig.update_xaxes(
    title_text="Control FDR", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=2, col=1
)
fig.update_yaxes(
    title_text="Dimension=200 <br><br>Real FDR", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=2, col=1
)

################################################################################
# Subplot 2 2
################################################################################
temp_df = r2_02.groupby('alpha').FDR.mean().reset_index()

trace1_sub2 = go.Scatter(
    x=temp_df.alpha.values,
    y=temp_df.FDR.values,
    mode='lines',
    name='DNetFinder, p=100',
    line=dict(color='blue'),
    showlegend=False
)

trace2_sub2 = go.Scatter(
    x=runs_qs_list_02[run_number],
    y=runs_fdr_list_02[run_number],
    mode='lines',
    name='Our Method, p=100',
    line=dict(color='red'),
    showlegend=False
)

trace3_sub2 = go.Scatter(
    x=[min(runs_qs_list_02[run_number]), max(runs_qs_list_02[run_number])],
    y=[min(runs_qs_list_02[run_number]), max(runs_qs_list_02[run_number])],
    mode='lines',
    name="f(x) = x",
    line=dict(color='black', dash='dash'),
    showlegend=False
)

fig.add_trace(trace1_sub2, row=2, col=2)
fig.add_trace(trace2_sub2, row=2, col=2)
fig.add_trace(trace3_sub2, row=2, col=2)

fig.update_xaxes(
    title_text="Control FDR", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=2, col=2
)
fig.update_yaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=2, col=2
)

################################################################################
# Subplot 2 3
################################################################################
temp_df = r2_04.groupby('alpha').FDR.mean().reset_index()

trace1_sub6 = go.Scatter(
    x=temp_df.alpha.values,
    y=temp_df.FDR.values,
    mode='lines',
    name='DNetFinder, p=100',
    line=dict(color='blue'),
    showlegend=False
)

trace2_sub6 = go.Scatter(
    x=runs_qs_list_04[run_number],
    y=runs_fdr_list_04[run_number],
    mode='lines',
    name='Our Method, p=100',
    line=dict(color='red'),
    showlegend=False
)

trace3_sub6 = go.Scatter(
    x=[min(runs_qs_list_04[run_number]), max(runs_qs_list_04[run_number])],
    y=[min(runs_qs_list_04[run_number]), max(runs_qs_list_04[run_number])],
    mode='lines',
    name="f(x) = x",
    line=dict(color='black', dash='dash'),
    showlegend=False
)

fig.add_trace(trace1_sub6, row=2, col=3)
fig.add_trace(trace2_sub6, row=2, col=3)
fig.add_trace(trace3_sub6, row=2, col=3)

fig.update_xaxes(
    title_text="Control FDR", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=2, col=3
)
fig.update_yaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=2, col=3
)

################################################################################
# Subplot 2 4
################################################################################
temp_df = r2_06.groupby('alpha').FDR.mean().reset_index()

trace1_sub4 = go.Scatter(
    x=temp_df.alpha.values,
    y=temp_df.FDR.values,
    mode='lines',
    name='DNetFinder, p=100',
    line=dict(color='blue'),
    showlegend=False
)

trace2_sub4 = go.Scatter(
    x=runs_qs_list_06[run_number],
    y=runs_fdr_list_06[run_number],
    mode='lines',
    name='Our Method, p=100',
    line=dict(color='red'),
    showlegend=False
)

trace3_sub4 = go.Scatter(
    x=[min(runs_qs_list_06[run_number]), max(runs_qs_list_06[run_number])],
    y=[min(runs_qs_list_06[run_number]), max(runs_qs_list_06[run_number])],
    mode='lines',
    name="f(x) = x",
    line=dict(color='black', dash='dash'),
    showlegend=False
)

fig.add_trace(trace1_sub4, row=2, col=4)
fig.add_trace(trace2_sub4, row=2, col=4)
fig.add_trace(trace3_sub4, row=2, col=4)

fig.update_xaxes(
    title_text="Control FDR", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=2, col=4
)
fig.update_yaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=2, col=4
)
################################################################################
# Subplot 2 5
################################################################################
temp_df = r2_08.groupby('alpha').FDR.mean().reset_index()

trace1_sub5 = go.Scatter(
    x=temp_df.alpha.values,
    y=temp_df.FDR.values,
    mode='lines',
    name='DNetFinder, p=100',
    line=dict(color='blue'),
    showlegend=False
)

trace2_sub5 = go.Scatter(
    x=runs_qs_list_08[run_number],
    y=runs_fdr_list_08[run_number],
    mode='lines',
    name='Our Method, p=100',
    line=dict(color='red'),
    showlegend=False
)

trace3_sub5 = go.Scatter(
    x=[min(runs_qs_list_08[run_number]), max(runs_qs_list_08[run_number])],
    y=[min(runs_qs_list_08[run_number]), max(runs_qs_list_08[run_number])],
    mode='lines',
    name="f(x) = x",
    line=dict(color='black', dash='dash'),
    showlegend=False
)

fig.add_trace(trace1_sub5, row=2, col=5)
fig.add_trace(trace2_sub5, row=2, col=5)
fig.add_trace(trace3_sub5, row=2, col=5)

fig.update_xaxes(
    title_text="Control FDR", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=2, col=5
)
fig.update_yaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=2, col=5
)

################################################################################
# Subplot 2 4
################################################################################
temp_df = r2_10.groupby('alpha').FDR.mean().reset_index()

trace1_sub6 = go.Scatter(
    x=temp_df.alpha.values,
    y=temp_df.FDR.values,
    mode='lines',
    name='DNetFinder, p=100',
    line=dict(color='blue'),
    showlegend=False
)

trace2_sub6 = go.Scatter(
    x=runs_qs_list_10[run_number],
    y=runs_fdr_list_10[run_number],
    mode='lines',
    name='Our Method, p=100',
    line=dict(color='red'),
    showlegend=False
)

trace3_sub6 = go.Scatter(
    x=[min(runs_qs_list_10[run_number]), max(runs_qs_list_10[run_number])],
    y=[min(runs_qs_list_10[run_number]), max(runs_qs_list_10[run_number])],
    mode='lines',
    name="f(x) = x",
    line=dict(color='black', dash='dash', width=3),
    showlegend=False,
)

fig.add_trace(trace1_sub6, row=2, col=6)
fig.add_trace(trace2_sub6, row=2, col=6)
fig.add_trace(trace3_sub6, row=2, col=6)

fig.update_xaxes(
    title_text="Control FDR", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=2, col=6
)
fig.update_yaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=2, col=6
)


################################################################################
# Global Layout (Only Subplot 1's traces appear in the legend)
################################################################################
fig.update_traces(line=dict(width=3))
fig.update_layout(
    xaxis1=dict(tickfont=dict(size=16),showticklabels=False),
    xaxis2=dict(tickfont=dict(size=16),showticklabels=False),
    xaxis3=dict(tickfont=dict(size=16),showticklabels=False),
    xaxis4=dict(tickfont=dict(size=16),showticklabels=False),
    xaxis5=dict(tickfont=dict(size=16),showticklabels=False),
    xaxis6=dict(tickfont=dict(size=16),showticklabels=False),
    xaxis7=dict(tickfont=dict(size=16)),
    xaxis8=dict(tickfont=dict(size=16)),
    xaxis9=dict(tickfont=dict(size=16)),
    xaxis10=dict(tickfont=dict(size=16)),
    xaxis11=dict(tickfont=dict(size=16)),
    xaxis12=dict(tickfont=dict(size=16)),
    yaxis1=dict(tickfont=dict(size=16)),
    yaxis2=dict(tickfont=dict(size=16),showticklabels=False),
    yaxis3=dict(tickfont=dict(size=16),showticklabels=False),
    yaxis4=dict(tickfont=dict(size=16),showticklabels=False),
    yaxis5=dict(tickfont=dict(size=16),showticklabels=False),
    yaxis6=dict(tickfont=dict(size=16),showticklabels=False),
    yaxis7=dict(tickfont=dict(size=16)),
    yaxis8=dict(tickfont=dict(size=16),showticklabels=False),
    yaxis9=dict(tickfont=dict(size=16),showticklabels=False),
    yaxis10=dict(tickfont=dict(size=16),showticklabels=False),
    yaxis11=dict(tickfont=dict(size=16),showticklabels=False),
    yaxis12=dict(tickfont=dict(size=16),showticklabels=False),
    autosize=False,
    width=2000,
    height=700,
    plot_bgcolor='white',
    paper_bgcolor='white',
    margin=dict(l=50, r=50, t=50, b=50),
    showlegend=True,
    legend=dict(
        x=0.005,
        y=0.995,
        xanchor='left',
        yanchor='top',
        bgcolor='white',
        bordercolor='gray',
        borderwidth=1
    ),
    font=dict(size=16)
)

fig.show()

fig.write_image("Results/erdos.pdf")

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Create the 4-row, 1-column subplot figure
fig = make_subplots(
    rows=2, cols=6,
    shared_xaxes=False,     
    vertical_spacing=0.07,  
    subplot_titles=["(a)", "(b)", "(c)", "(d)", "(e)", "(f)"]
)

################################################################################
# Subplot 1 a
################################################################################
temp_df = r1_00.groupby('alpha').TPR.mean().reset_index()
temp_dfx = x1_00.groupby('alpha').TPR.mean().reset_index()
run_number = 0

trace1_sub1 = go.Scatter(
    x=temp_df.alpha.values,
    y=temp_df.TPR.values,
    mode='lines',
    name='pcor',
    line=dict(color='blue'),    # <--- Explicit color
    showlegend=True
)

trace1x_sub1 = go.Scatter(
    x=temp_dfx.alpha.values,
    y=temp_dfx.TPR.values,
    mode='lines',
    name='pmat',
    line=dict(color='green'),    # <--- Explicit color
    showlegend=True
)

trace2_sub1 = go.Scatter(
    x=runs_qs_list_00[run_number],
    y=runs_recall_list_00[run_number],
    mode='lines',
    name='DNetEx',
    line=dict(color='red'),     # <--- Explicit color
    showlegend=True
)

trace3_sub1 = go.Scatter(
    x=[min(runs_qs_list_00[run_number]), max(runs_qs_list_00[run_number])],
    y=[min(runs_qs_list_00[run_number]), max(runs_qs_list_00[run_number])],
    mode='lines',
    name="f(x) = x",
    line=dict(color='black', dash='dash'),  # <--- Explicit color/dash
    showlegend=True
)

fig.add_trace(trace1_sub1, row=1, col=1)
fig.add_trace(trace1x_sub1, row=1, col=1)
fig.add_trace(trace2_sub1, row=1, col=1)
fig.add_trace(trace3_sub1, row=1, col=1)

fig.update_xaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=1, col=1
)
fig.update_yaxes(
    title_text="Dimension1=00 <br><br> Real TPR", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=1, col=1
)

################################################################################
# Subplot 2 b
################################################################################
temp_df = r1_02.groupby('alpha').TPR.mean().reset_index()
temp_dfx = x1_02.groupby('alpha').TPR.mean().reset_index()

trace1_sub2 = go.Scatter(
    x=temp_df.alpha.values,
    y=temp_df.TPR.values,
    mode='lines',
    name='pcor',
    line=dict(color='blue'),
    showlegend=False
)

trace1x_sub2 = go.Scatter(
    x=temp_dfx.alpha.values,
    y=temp_dfx.TPR.values,
    mode='lines',
    name='pmat',
    line=dict(color='green'),
    showlegend=False
)

trace2_sub2 = go.Scatter(
    x=runs_qs_list_02[run_number],
    y=runs_recall_list_02[run_number],
    mode='lines',
    name='Our Method, p=100',
    line=dict(color='red'),
    showlegend=False
)

trace3_sub2 = go.Scatter(
    x=[min(runs_qs_list_02[run_number]), max(runs_qs_list_02[run_number])],
    y=[min(runs_qs_list_02[run_number]), max(runs_qs_list_02[run_number])],
    mode='lines',
    name="f(x) = x",
    line=dict(color='black', dash='dash'),
    showlegend=False
)

fig.add_trace(trace1_sub2, row=1, col=2)
fig.add_trace(trace1x_sub2, row=1, col=2)
fig.add_trace(trace2_sub2, row=1, col=2)
fig.add_trace(trace3_sub2, row=1, col=2)

fig.update_xaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=1, col=2
)
fig.update_yaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=1, col=2
)
################################################################################
# Subplot 3 c
################################################################################
temp_df = r1_04.groupby('alpha').TPR.mean().reset_index()
temp_dfx = x1_04.groupby('alpha').TPR.mean().reset_index()

trace1_sub3 = go.Scatter(
    x=temp_df.alpha.values,
    y=temp_df.TPR.values,
    mode='lines',
    name='pcor',
    line=dict(color='blue'),
    showlegend=False
)

trace1x_sub3 = go.Scatter(
    x=temp_dfx.alpha.values,
    y=temp_dfx.TPR.values,
    mode='lines',
    name='pmat',
    line=dict(color='green'),
    showlegend=False
)

trace2_sub3 = go.Scatter(
    x=runs_qs_list_04[run_number],
    y=runs_recall_list_04[run_number],
    mode='lines',
    name='Our Method, p=100',
    line=dict(color='red'),
    showlegend=False
)

trace3_sub3 = go.Scatter(
    x=[min(runs_qs_list_04[run_number]), max(runs_qs_list_04[run_number])],
    y=[min(runs_qs_list_04[run_number]), max(runs_qs_list_04[run_number])],
    mode='lines',
    name="f(x) = x",
    line=dict(color='black', dash='dash'),
    showlegend=False
)

fig.add_trace(trace1_sub3, row=1, col=3)
fig.add_trace(trace1x_sub3, row=1, col=3)
fig.add_trace(trace2_sub3, row=1, col=3)
fig.add_trace(trace3_sub3, row=1, col=3)

fig.update_xaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=1, col=3
)
fig.update_yaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=1, col=3
)

################################################################################
# Subplot 4 d
################################################################################
temp_df = r1_06.groupby('alpha').TPR.mean().reset_index()
temp_dfx = x1_06.groupby('alpha').TPR.mean().reset_index()

trace1_sub4 = go.Scatter(
    x=temp_df.alpha.values,
    y=temp_df.TPR.values,
    mode='lines',
    name='pcor',
    line=dict(color='blue'),
    showlegend=False
)

trace1x_sub4 = go.Scatter(
    x=temp_dfx.alpha.values,
    y=temp_dfx.TPR.values,
    mode='lines',
    name='pmat',
    line=dict(color='green'),
    showlegend=False
)

trace2_sub4 = go.Scatter(
    x=runs_qs_list_06[run_number],
    y=runs_recall_list_06[run_number],
    mode='lines',
    name='Our Method, p=100',
    line=dict(color='red'),
    showlegend=False
)

trace3_sub4 = go.Scatter(
    x=[min(runs_qs_list_06[run_number]), max(runs_qs_list_06[run_number])],
    y=[min(runs_qs_list_06[run_number]), max(runs_qs_list_06[run_number])],
    mode='lines',
    name="f(x) = x",
    line=dict(color='black', dash='dash'),
    showlegend=False
)

fig.add_trace(trace1_sub4, row=1, col=4)
fig.add_trace(trace1x_sub4, row=1, col=4)
fig.add_trace(trace2_sub4, row=1, col=4)
fig.add_trace(trace3_sub4, row=1, col=4)

fig.update_xaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=1, col=4
)
fig.update_yaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=1, col=4
)

################################################################################
# Subplot 5 e
################################################################################
temp_df = r1_08.groupby('alpha').TPR.mean().reset_index()
temp_dfx = x1_08.groupby('alpha').TPR.mean().reset_index()

trace1_sub5 = go.Scatter(
    x=temp_df.alpha.values,
    y=temp_df.TPR.values,
    mode='lines',
    name='pcor',
    line=dict(color='blue'),
    showlegend=False
)

trace1x_sub5 = go.Scatter(
    x=temp_dfx.alpha.values,
    y=temp_dfx.TPR.values,
    mode='lines',
    name='pmat',
    line=dict(color='green'),
    showlegend=False
)

trace2_sub5 = go.Scatter(
    x=runs_qs_list_08[run_number],
    y=runs_recall_list_08[run_number],
    mode='lines',
    name='Our Method, p=100',
    line=dict(color='red'),
    showlegend=False
)

trace3_sub5 = go.Scatter(
    x=[min(runs_qs_list_08[run_number]), max(runs_qs_list_08[run_number])],
    y=[min(runs_qs_list_08[run_number]), max(runs_qs_list_08[run_number])],
    mode='lines',
    name="f(x) = x",
    line=dict(color='black', dash='dash'),
    showlegend=False
)

fig.add_trace(trace1_sub5, row=1, col=5)
fig.add_trace(trace1x_sub5, row=1, col=5)
fig.add_trace(trace2_sub5, row=1, col=5)
fig.add_trace(trace3_sub5, row=1, col=5)

fig.update_xaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=1, col=5
)
fig.update_yaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=1, col=5
)

################################################################################
# Subplot 6
################################################################################
temp_df = r1_10.groupby('alpha').TPR.mean().reset_index()
temp_dfx = x1_10.groupby('alpha').TPR.mean().reset_index()

trace1_sub6 = go.Scatter(
    x=temp_df.alpha.values,
    y=temp_df.TPR.values,
    mode='lines',
    name='pcor',
    line=dict(color='blue'),
    showlegend=False
)

trace1x_sub6 = go.Scatter(
    x=temp_dfx.alpha.values,
    y=temp_dfx.TPR.values,
    mode='lines',
    name='pmat',
    line=dict(color='green'),
    showlegend=False
)

trace2_sub6 = go.Scatter(
    x=runs_qs_list_10[run_number],
    y=runs_recall_list_10[run_number],
    mode='lines',
    name='Our Method, p=100',
    line=dict(color='red'),
    showlegend=False
)

trace3_sub6 = go.Scatter(
    x=[min(runs_qs_list_10[run_number]), max(runs_qs_list_10[run_number])],
    y=[min(runs_qs_list_10[run_number]), max(runs_qs_list_10[run_number])],
    mode='lines',
    name="f(x) = x",
    line=dict(color='black', dash='dash'),
    showlegend=False
)

fig.add_trace(trace1_sub6, row=1, col=6)
fig.add_trace(trace1x_sub6, row=1, col=6)
fig.add_trace(trace2_sub6, row=1, col=6)
fig.add_trace(trace3_sub6, row=1, col=6)

fig.update_xaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=1, col=6
)
fig.update_yaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=1, col=6
)



################################################################################
# Subplot 2 1
################################################################################
temp_df = r2_00.groupby('alpha').TPR.mean().reset_index()
temp_dfx = x2_00.groupby('alpha').TPR.mean().reset_index()
run_number = 0

trace1_sub1 = go.Scatter(
    x=temp_df.alpha.values,
    y=temp_df.TPR.values,
    mode='lines',
    name='pcor, p=100',
    line=dict(color='blue'),    # <--- Explicit color
    showlegend=False
)

trace1x_sub1 = go.Scatter(
    x=temp_dfx.alpha.values,
    y=temp_dfx.TPR.values,
    mode='lines',
    name='pmat, p=100',
    line=dict(color='green'),    # <--- Explicit color
    showlegend=False
)

trace2_sub1 = go.Scatter(
    x=runs_qs_list_00[run_number],
    y=runs_recall_list_00[run_number],
    mode='lines',
    name='Our Method, p=100',
    line=dict(color='red'),     # <--- Explicit color
    showlegend=False
)

trace3_sub1 = go.Scatter(
    x=[min(runs_qs_list_00[run_number]), max(runs_qs_list_00[run_number])],
    y=[min(runs_qs_list_00[run_number]), max(runs_qs_list_00[run_number])],
    mode='lines',
    name="f(x) = x",
    line=dict(color='black', dash='dash'),  # <--- Explicit color/dash
    showlegend=False
)

fig.add_trace(trace1_sub1, row=2, col=1)
fig.add_trace(trace1x_sub1, row=2, col=1)
fig.add_trace(trace2_sub1, row=2, col=1)
fig.add_trace(trace3_sub1, row=2, col=1)

fig.update_xaxes(
    title_text="Control TPR", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=2, col=1
)
fig.update_yaxes(
    title_text="Dimension=200 <br><br>Real TPR", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=2, col=1
)

################################################################################
# Subplot 2 2
################################################################################
temp_df = r2_02.groupby('alpha').TPR.mean().reset_index()

trace1_sub2 = go.Scatter(
    x=temp_df.alpha.values,
    y=temp_df.TPR.values,
    mode='lines',
    name='DNetFinder, p=100',
    line=dict(color='blue'),
    showlegend=False
)

trace2_sub2 = go.Scatter(
    x=runs_qs_list_02[run_number],
    y=runs_recall_list_02[run_number],
    mode='lines',
    name='Our Method, p=100',
    line=dict(color='red'),
    showlegend=False
)

trace3_sub2 = go.Scatter(
    x=[min(runs_qs_list_02[run_number]), max(runs_qs_list_02[run_number])],
    y=[min(runs_qs_list_02[run_number]), max(runs_qs_list_02[run_number])],
    mode='lines',
    name="f(x) = x",
    line=dict(color='black', dash='dash'),
    showlegend=False
)

fig.add_trace(trace1_sub2, row=2, col=2)
fig.add_trace(trace2_sub2, row=2, col=2)
fig.add_trace(trace3_sub2, row=2, col=2)

fig.update_xaxes(
    title_text="Control TPR", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=2, col=2
)
fig.update_yaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=2, col=2
)

################################################################################
# Subplot 2 3
################################################################################
temp_df = r2_04.groupby('alpha').TPR.mean().reset_index()

trace1_sub6 = go.Scatter(
    x=temp_df.alpha.values,
    y=temp_df.TPR.values,
    mode='lines',
    name='DNetFinder, p=100',
    line=dict(color='blue'),
    showlegend=False
)

trace2_sub6 = go.Scatter(
    x=runs_qs_list_04[run_number],
    y=runs_recall_list_04[run_number],
    mode='lines',
    name='Our Method, p=100',
    line=dict(color='red'),
    showlegend=False
)

trace3_sub6 = go.Scatter(
    x=[min(runs_qs_list_04[run_number]), max(runs_qs_list_04[run_number])],
    y=[min(runs_qs_list_04[run_number]), max(runs_qs_list_04[run_number])],
    mode='lines',
    name="f(x) = x",
    line=dict(color='black', dash='dash'),
    showlegend=False
)

fig.add_trace(trace1_sub6, row=2, col=3)
fig.add_trace(trace2_sub6, row=2, col=3)
fig.add_trace(trace3_sub6, row=2, col=3)

fig.update_xaxes(
    title_text="Control TPR", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=2, col=3
)
fig.update_yaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=2, col=3
)

################################################################################
# Subplot 2 4
################################################################################
temp_df = r2_06.groupby('alpha').TPR.mean().reset_index()

trace1_sub4 = go.Scatter(
    x=temp_df.alpha.values,
    y=temp_df.TPR.values,
    mode='lines',
    name='DNetFinder, p=100',
    line=dict(color='blue'),
    showlegend=False
)

trace2_sub4 = go.Scatter(
    x=runs_qs_list_06[run_number],
    y=runs_recall_list_06[run_number],
    mode='lines',
    name='Our Method, p=100',
    line=dict(color='red'),
    showlegend=False
)

trace3_sub4 = go.Scatter(
    x=[min(runs_qs_list_06[run_number]), max(runs_qs_list_06[run_number])],
    y=[min(runs_qs_list_06[run_number]), max(runs_qs_list_06[run_number])],
    mode='lines',
    name="f(x) = x",
    line=dict(color='black', dash='dash'),
    showlegend=False
)

fig.add_trace(trace1_sub4, row=2, col=4)
fig.add_trace(trace2_sub4, row=2, col=4)
fig.add_trace(trace3_sub4, row=2, col=4)

fig.update_xaxes(
    title_text="Control TPR", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=2, col=4
)
fig.update_yaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=2, col=4
)
################################################################################
# Subplot 2 5
################################################################################
temp_df = r2_08.groupby('alpha').TPR.mean().reset_index()

trace1_sub5 = go.Scatter(
    x=temp_df.alpha.values,
    y=temp_df.TPR.values,
    mode='lines',
    name='DNetFinder, p=100',
    line=dict(color='blue'),
    showlegend=False
)

trace2_sub5 = go.Scatter(
    x=runs_qs_list_08[run_number],
    y=runs_recall_list_08[run_number],
    mode='lines',
    name='Our Method, p=100',
    line=dict(color='red'),
    showlegend=False
)

trace3_sub5 = go.Scatter(
    x=[min(runs_qs_list_08[run_number]), max(runs_qs_list_08[run_number])],
    y=[min(runs_qs_list_08[run_number]), max(runs_qs_list_08[run_number])],
    mode='lines',
    name="f(x) = x",
    line=dict(color='black', dash='dash'),
    showlegend=False
)

fig.add_trace(trace1_sub5, row=2, col=5)
fig.add_trace(trace2_sub5, row=2, col=5)
fig.add_trace(trace3_sub5, row=2, col=5)

fig.update_xaxes(
    title_text="Control TPR", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=2, col=5
)
fig.update_yaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=2, col=5
)

################################################################################
# Subplot 2 4
################################################################################
temp_df = r2_10.groupby('alpha').TPR.mean().reset_index()

trace1_sub6 = go.Scatter(
    x=temp_df.alpha.values,
    y=temp_df.TPR.values,
    mode='lines',
    name='DNetFinder, p=100',
    line=dict(color='blue'),
    showlegend=False
)

trace2_sub6 = go.Scatter(
    x=runs_qs_list_10[run_number],
    y=runs_recall_list_10[run_number],
    mode='lines',
    name='Our Method, p=100',
    line=dict(color='red'),
    showlegend=False
)

trace3_sub6 = go.Scatter(
    x=[min(runs_qs_list_10[run_number]), max(runs_qs_list_10[run_number])],
    y=[min(runs_qs_list_10[run_number]), max(runs_qs_list_10[run_number])],
    mode='lines',
    name="f(x) = x",
    line=dict(color='black', dash='dash', width=3),
    showlegend=False,
)

fig.add_trace(trace1_sub6, row=2, col=6)
fig.add_trace(trace2_sub6, row=2, col=6)
fig.add_trace(trace3_sub6, row=2, col=6)

fig.update_xaxes(
    title_text="Control TPR", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=2, col=6
)
fig.update_yaxes(
    title_text="", 
    showline=True, linewidth=2, linecolor='black', mirror=True,
    row=2, col=6
)


################################################################################
# Global Layout (Only Subplot 1's traces appear in the legend)
################################################################################
fig.update_traces(line=dict(width=3))
fig.update_layout(
    xaxis1=dict(tickfont=dict(size=16),showticklabels=False),
    xaxis2=dict(tickfont=dict(size=16),showticklabels=False),
    xaxis3=dict(tickfont=dict(size=16),showticklabels=False),
    xaxis4=dict(tickfont=dict(size=16),showticklabels=False),
    xaxis5=dict(tickfont=dict(size=16),showticklabels=False),
    xaxis6=dict(tickfont=dict(size=16),showticklabels=False),
    xaxis7=dict(tickfont=dict(size=16)),
    xaxis8=dict(tickfont=dict(size=16)),
    xaxis9=dict(tickfont=dict(size=16)),
    xaxis10=dict(tickfont=dict(size=16)),
    xaxis11=dict(tickfont=dict(size=16)),
    xaxis12=dict(tickfont=dict(size=16)),
    yaxis1=dict(tickfont=dict(size=16)),
    yaxis2=dict(tickfont=dict(size=16),showticklabels=False),
    yaxis3=dict(tickfont=dict(size=16),showticklabels=False),
    yaxis4=dict(tickfont=dict(size=16),showticklabels=False),
    yaxis5=dict(tickfont=dict(size=16),showticklabels=False),
    yaxis6=dict(tickfont=dict(size=16),showticklabels=False),
    yaxis7=dict(tickfont=dict(size=16)),
    yaxis8=dict(tickfont=dict(size=16),showticklabels=False),
    yaxis9=dict(tickfont=dict(size=16),showticklabels=False),
    yaxis10=dict(tickfont=dict(size=16),showticklabels=False),
    yaxis11=dict(tickfont=dict(size=16),showticklabels=False),
    yaxis12=dict(tickfont=dict(size=16),showticklabels=False),
    autosize=False,
    width=2000,
    height=700,
    plot_bgcolor='white',
    paper_bgcolor='white',
    margin=dict(l=50, r=50, t=50, b=50),
    showlegend=True,
    legend=dict(
        x=0.005,
        y=0.995,
        xanchor='left',
        yanchor='top',
        bgcolor='white',
        bordercolor='gray',
        borderwidth=1
    ),
    font=dict(size=16)
)

fig.show()

fig.write_image("Results/erdos_power.pdf")
